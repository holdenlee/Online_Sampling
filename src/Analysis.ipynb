# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import importlib
import os
import sys

from base.experiment import *
from logistic.env_logistic import *
from logistic.agent_logistic import *
from utils import *

import copy
import numpy as np
import math
import matplotlib.pyplot as plt
import numpy.linalg as npla
import scipy.linalg as spla
import pandas as pd
import plotnine as gg
import pickle
import warnings
warnings.filterwarnings('ignore')

from agents import *
from compare_utils import *
from graph_utils import *

# %%
name = '../outputs/compare/compare'
results_list = []
regrets_list = []
for i in range(71):
    results = pd.read_pickle(open('%s_%d_results.p' % (name, i), 'rb'))
    regrets = pickle.load(open('%s_%d_regrets.p' % (name, i), 'rb'))
    results_list += [results]
    regrets_list += [regrets]
regrets = np.asarray(regrets_list)
avg_regrets = np.mean(regrets, axis=0)

# %%
avg_regrets
# Out:
# array([ 61.39245634,  50.94552942, 142.83610336,  50.83556212,
#         80.32249089])

# %%
name = '../outputs/compare_0_1_trials_1000_seed'
results_list = []
regrets_list = []
for i in range(1,101):
    results = pd.read_pickle(open('%s_results_%d.p' % (name, i), 'rb'))
    regrets = pickle.load(open('%s_regrets_%d.p' % (name, i), 'rb'))
    results_list += [results]
    regrets_list += [regrets]
regrets = np.asarray(regrets_list)
avg_regrets = np.mean(regrets, axis=0)

# %%
avg_regrets
# Out:
# array([ 46.57367412,  68.66705727,  61.77800763,  54.42978961,
#         54.519837  , 147.38032253,  53.07343985,  95.84195687,
#         96.79314336])

# %%
for i in range(1,36):
    plot_results([results_list[i]])
# Out:
# <ggplot: (8762530012361)>
# <ggplot: (8762530012377)>
# <ggplot: (8762530032233)>
# <ggplot: (8762527079869)>
# <ggplot: (8762527318293)>
# <ggplot: (8762702759485)>
# <ggplot: (8762702702605)>
# <ggplot: (8762527243013)>
# <ggplot: (8762527005733)>
# <ggplot: (8762702419137)>
# <ggplot: (8762526696533)>
# <ggplot: (8762526347293)>
# <ggplot: (8762527121117)>
# <ggplot: (8762526100389)>
# <ggplot: (8762526012685)>
# <ggplot: (8762525933225)>
# <ggplot: (8762526384701)>
# <ggplot: (8762530009937)>
# <ggplot: (8762526770013)>
# <ggplot: (8762529967893)>
# <ggplot: (8762702816089)>
# <ggplot: (8762527290313)>
# <ggplot: (8762526384765)>
# <ggplot: (8762526384869)>
# <ggplot: (8762526384765)>
# <ggplot: (8762526520173)>
# <ggplot: (8762537614073)>
# <ggplot: (8762527111881)>
# <ggplot: (8762526015145)>
# <ggplot: (8762526141641)>
# <ggplot: (8762527308329)>
# <ggplot: (8762702737753)>
# <ggplot: (8762525994421)>
# <ggplot: (8762527303845)>
# <ggplot: (8762526152485)>
# <ggplot: (8762702650097)>
# <ggplot: (8762702419181)>
# <ggplot: (8762702649885)>
# <ggplot: (8762526744181)>
# <ggplot: (8762526922237)>
# <ggplot: (8762702456889)>
# <ggplot: (8762526011397)>
# <ggplot: (8762702705137)>
# <ggplot: (8762527197921)>
# <ggplot: (8762530077453)>
# <ggplot: (8762702360437)>
# <ggplot: (8762702642661)>
# <ggplot: (8762529979865)>
# <ggplot: (8762702598001)>
# <ggplot: (8762526764949)>
# <ggplot: (8762527121057)>
# <ggplot: (8762526997641)>
# <ggplot: (8762526011421)>
# <ggplot: (8762526997661)>
# <ggplot: (8762526997717)>
# <ggplot: (8762527079753)>
# <ggplot: (8762527208017)>
# <ggplot: (8762527208033)>
# <ggplot: (8762530010033)>
# <ggplot: (8762702597917)>
# <ggplot: (8762526782497)>
# <ggplot: (8762527338549)>
# <ggplot: (8762530032285)>
# <ggplot: (8762526683733)>
# <ggplot: (8762702641813)>
# <ggplot: (8762526146197)>
# <ggplot: (8762526683765)>
# <ggplot: (8762526872777)>
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-11-370114d8d7c7> in <module>()
#       1 for i in range(1,36):
# ----> 2     plot_results([results_list[i]])
#
# IndexError: list index out of range

# %%
name = '../outputs/compare/compare'
results_list = []
regrets_list = []
for i in range(1,40):
    results = pd.read_pickle(open('%s_%d_results.p' % (name, i), 'rb'))
    regrets = pickle.load(open('%s_%d_regrets.p' % (name, i), 'rb'))
    results_list += [results]
    regrets_list += [regrets]
regrets = np.asarray(regrets_list)
avg_regrets = np.mean(regrets, axis=0)
print(avg_regrets)
# Out:
# [ 51.01351375  44.36419333 122.6788696   43.79379715  53.00362352]
