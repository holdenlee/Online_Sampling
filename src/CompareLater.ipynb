# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import importlib
import os
import sys

from base.experiment import *
from logistic.env_logistic import *
from logistic.agent_logistic import *
from utils import *

import copy
import numpy as np
import math
#import matplotlib.pyplot as plt
import numpy.linalg as npla
import scipy.linalg as spla
#import pandas as pd
#import plotnine as gg
import pickle
import warnings
warnings.filterwarnings('ignore')

from agents import *
from compare_utils import *
#from graph_utils import *

time_limit= 0.1 #float(sys.argv[1])
T= 2000 #int(sys.argv[2])
toggle_at = 1000
name= 'outputs/compare_later/seed'#sys.argv[3]
seeds = 100 #int(sys.argv[4])

num_articles = 100
dim = 20
dim1= dim+1
sparsity = 5.0
theta_mean = 0
theta_std = 1

verbosity=1

batch_size = 64

for seed in range(seeds):
    agents = make_default_agents(num_articles, dim, sparsity, time_limit, verbosity=verbosity, batch_size=batch_size, bias_term=True)
    results, cum_regrets = simple_compare(agents, num_articles, dim, sparsity, T, seed, verbosity=verbosity, dist_type='Bernoulli', toggle_at=toggle_at)
    print(results)
    print(cum_regrets)
    pickle.dump(results, open('%s_%d_results.p' % (name, seed),'wb'))
    pickle.dump(cum_regrets, open('%s_%d_regrets.p' % (name, seed),'wb'))
# Out:
# theta [ 1.76405235  0.40015721  0.97873798  2.2408932   1.86755799 -0.97727788
#   0.95008842 -0.15135721 -0.10321885  0.4105985   0.14404357  1.45427351
#   0.76103773  0.12167502  0.44386323  0.33367433  1.49407907 -0.20515826
#   0.3130677  -0.85409574 -2.55298982]
# Experiment: Step 0
#  Accept proportion: 0.973913
#  Steps taken: 115
#  Cum regret: 0.000950
#  Cum regret: 0.000950
#  Cum regret: 0.000950
#  Cum regret: 0.000950
#  Steps taken: 536
#  Cum regret: 0.000950
#  Steps taken: 0
#  Cum regret: 0.000950
#  Steps taken: 0
#  Cum regret: 0.000950
#  Steps taken: 0
#  Cum regret: 0.000950
#  Steps taken: 0
#  Cum regret: 0.000950
# Experiment: Step 1
#  Accept proportion: 0.990291
#  Steps taken: 206
#  Cum regret: 0.015210
#  Cum regret: 0.015210
#  Cum regret: 0.015210
#  Steps taken: 10
#  Cum regret: 0.015210
#  Steps taken: 787
#  Cum regret: 0.015210
#  Steps taken: 1075
#  Cum regret: 0.015210
#  Steps taken: 808
#  Cum regret: 0.015210
#  Steps taken: 1
#  Cum regret: 0.015210
#  Steps taken: 37
#  Cum regret: 0.015210
# Experiment: Step 2
#  Accept proportion: 0.950000
#  Steps taken: 40
#  Cum regret: 0.101005
#  Cum regret: 0.101005
#  Cum regret: 0.101005
#  Steps taken: 8
#  Cum regret: 0.101005
#  Steps taken: 221
#  Cum regret: 0.101005
#  Steps taken: 372
#  Cum regret: 0.101005
#  Steps taken: 408
#  Cum regret: 0.101005
#  Steps taken: 1
#  Cum regret: 0.101005
#  Steps taken: 32
#  Cum regret: 0.101005
# Experiment: Step 3
#  Accept proportion: 0.966346
#  Steps taken: 208
#  Cum regret: 0.503785
#  Cum regret: 0.503785
#  Cum regret: 0.503785
#  Steps taken: 11
#  Cum regret: 0.503785
#  Steps taken: 377
#  Cum regret: 0.503785
#  Steps taken: 688
#  Cum regret: 0.503785
#  Steps taken: 806
#  Cum regret: 0.503785
#  Steps taken: 1
#  Cum regret: 0.503785
#  Steps taken: 71
#  Cum regret: 0.503785
# Experiment: Step 4
#  Accept proportion: 0.975000
#  Steps taken: 80
#  Cum regret: 0.723515
#  Cum regret: 0.723515
#  Cum regret: 0.723515
#  Steps taken: 217
#  Cum regret: 0.723515
#  Steps taken: 824
#  Cum regret: 0.723515
#  Steps taken: 685
#  Cum regret: 0.723515
#  Steps taken: 818
#  Cum regret: 0.723515
#  Steps taken: 1
#  Cum regret: 0.723515
#  Steps taken: 62
#  Cum regret: 0.723515
# Experiment: Step 5
#  Accept proportion: 0.995098
#  Steps taken: 204
#  Cum regret: 1.406299
#  Cum regret: 1.406299
#  Cum regret: 1.406299
#  Steps taken: 8
#  Cum regret: 1.406299
#  Steps taken: 576
#  Cum regret: 1.406299
#  Steps taken: 882
#  Cum regret: 1.406299
#  Steps taken: 776
#  Cum regret: 1.406299
#  Steps taken: 1
#  Cum regret: 1.406299
#  Steps taken: 188
#  Cum regret: 1.406299
# Experiment: Step 6
#  Accept proportion: 0.985714
#  Steps taken: 210
#  Cum regret: 1.407262
#  Cum regret: 1.407262
#  Cum regret: 1.407262
#  Steps taken: 5
#  Cum regret: 1.407262
#  Steps taken: 441
#  Cum regret: 1.407262
#  Steps taken: 900
#  Cum regret: 1.407262
#  Steps taken: 751
#  Cum regret: 1.407262
#  Steps taken: 1
#  Cum regret: 1.407262
#  Steps taken: 32
#  Cum regret: 1.407262
# Experiment: Step 7
#  Accept proportion: 0.980198
#  Steps taken: 202
#  Cum regret: 1.423393
#  Cum regret: 1.423393
#  Cum regret: 1.423393
#  Steps taken: 9
#  Cum regret: 1.423393
#  Steps taken: 352
#  Cum regret: 1.423393
#  Steps taken: 684
#  Cum regret: 1.423393
#  Steps taken: 788
#  Cum regret: 1.423393
#  Steps taken: 1
#  Cum regret: 1.423393
#  Steps taken: 87
#  Cum regret: 1.423393
# Experiment: Step 8
#  Accept proportion: 0.982759
#  Steps taken: 58
#  Cum regret: 1.584810
#  Cum regret: 1.584810
#  Cum regret: 1.584810
#  Steps taken: 23
#  Cum regret: 1.584810
#  Steps taken: 332
#  Cum regret: 1.584810
#  Steps taken: 814
#  Cum regret: 1.584810
#  Steps taken: 779
#  Cum regret: 1.584810
#  Steps taken: 1
#  Cum regret: 1.584810
#  Steps taken: 83
#  Cum regret: 1.584810
# Experiment: Step 9
#  Accept proportion: 0.995327
#  Steps taken: 214
#  Cum regret: 1.586939
#  Cum regret: 1.586939
#  Cum regret: 1.586939
#  Steps taken: 44
#  Cum regret: 1.586939
#  Steps taken: 400
#  Cum regret: 1.586939
#  Steps taken: 645
#  Cum regret: 1.586939
#  Steps taken: 773
#  Cum regret: 1.586939
#  Steps taken: 1
#  Cum regret: 1.586939
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-910303b112be> in <module>()
#      46
#      47 agents = make_default_agents(num_articles, dim, sparsity, time_limit, verbosity=verbosity, batch_size=batch_size, bias_term=True)
# ---> 48 results, cum_regrets = simple_compare(agents, num_articles, dim, sparsity, T, seed, verbosity=verbosity, dist_type='Bernoulli', toggle_at=toggle_at)
#      49 print(results)
#      50 print(cum_regrets)
#
# /n/fs/grad/holdenl/code/ts_tutorial/src/compare_utils.py in simple_compare(agents, num_articles, dim, sparsity, n_steps, seed, verbosity, force, graph, dist_type, toggle_at)
#     111     experiment = ExperimentCompare(agents, env, n_steps,
#     112                    seed=seed, verbosity=verbosity, force=force, toggle_at=toggle_at)
# --> 113     experiment.run_experiment()
#     114     results = []
#     115     results.append(experiment.results)
#
# /n/fs/grad/holdenl/code/ts_tutorial/src/base/experiment.py in run_experiment(self)
#     319         self.force=False
#     320       printv("Experiment: Step %d" % t, self.v, 1)
# --> 321       self.run_step_maybe_log(t)
#     322
#     323     self.results = pd.DataFrame(self.results)
#
# /n/fs/grad/holdenl/code/ts_tutorial/src/base/experiment.py in run_step_maybe_log(self, t)
#     293         # Need to change to store for each
#     294         self.cum_regret[i] += instant_regret
# --> 295         printv(' Cum regret: %f' % self.cum_regret[i], self.v, 1)
#     296         if (t + 1) % self.rec_freq == 0:
#     297           self.data_dict = {'t': (t + 1),
#
# /n/fs/grad/holdenl/code/ts_tutorial/src/utils.pyc in printv(s, v, lim)
#     225 def printv(s, v, lim):
#     226     if v >= lim:
# --> 227         print(s)
#     228
#     229 """
#
# /u/holdenl/ts_tutorial/lib/python2.7/site-packages/ipykernel/iostream.pyc in write(self, string)
#     398             is_child = (not self._is_master_process())
#     399             # only touch the buffer in the IO thread to avoid races
# --> 400             self.pub_thread.schedule(lambda : self._buffer.write(string))
#     401             if is_child:
#     402                 # newlines imply flush in subprocesses
#
# /u/holdenl/ts_tutorial/lib/python2.7/site-packages/ipykernel/iostream.pyc in schedule(self, f)
#     201             self._events.append(f)
#     202             # wake event thread (message content is ignored)
# --> 203             self._event_pipe.send(b'')
#     204         else:
#     205             f()
#
# /u/holdenl/ts_tutorial/lib/python2.7/site-packages/zmq/sugar/socket.pyc in send(self, data, flags, copy, track, routing_id, group)
#     390                                  copy_threshold=self.copy_threshold)
#     391             data.group = group
# --> 392         return super(Socket, self).send(data, flags=flags, copy=copy, track=track)
#     393
#     394     def send_multipart(self, msg_parts, flags=0, copy=True, track=False, **kwargs):
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._send_copy()
#
# /u/holdenl/ts_tutorial/lib/python2.7/site-packages/zmq/backend/cython/checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#      10     """
#      11     cdef int errno = zmq_errno()
# ---> 12     PyErr_CheckSignals()
#      13     if rc == -1: # if rc < -1, it's a bug in libzmq. Should we warn?
#      14         if errno == EINTR:
#
# KeyboardInterrupt:
