# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import importlib
import os
import sys

from base.experiment import *
from logistic.env_logistic import *
from logistic.agent_logistic import *
from utils import *

import copy
import numpy as np
import math
import matplotlib.pyplot as plt
import numpy.linalg as npla
import scipy.linalg as spla
import pandas as pd
import plotnine as gg
import pickle
import warnings
warnings.filterwarnings('ignore')

from agents import *
from compare_utils import *
from graph_utils import *

# %%
seed=1

num_articles = 100
dim = 20
dim1= dim+1
sparsity = 5.0
theta_mean = 0
theta_std = 1

time_limit= 0.1

verbosity=1


T=1000
batch_size = 64

def make_mala(eta0):
    return MalaTS(num_articles, dim1, [0]*(dim1), cov=None, 
                                     step_size=lambda t: eta0/(1 + t * np.sqrt(sparsity/dim)), n_steps=9999,
                                     time = time_limit,
                                     init_pt=None, verbosity=verbosity, leapfrog=True)
agents = [make_mala(eta0) for eta0 in [2.0,1.0,0.5,0.2,0.1]]
results, cum_regrets = simple_compare(agents, num_articles, dim, sparsity, T, seed, verbosity=verbosity, dist_type='Bernoulli')
# Out:
# theta [ 1.62434536 -0.61175641 -0.52817175 -1.07296862  0.86540763 -2.3015387
#   1.74481176 -0.7612069   0.3190391  -0.24937038  1.46210794 -2.06014071
#  -0.3224172  -0.38405435  1.13376944 -1.09989127 -0.17242821 -0.87785842
#   0.04221375  0.58281521 -1.10061918]
# Experiment: Step 0
#  Accept proportion: 0.582633
#  Steps taken: 357
#  Cum regret: 0.347050
#  Accept proportion: 0.088083
#  Steps taken: 386
#  Cum regret: 0.018539
#  Accept proportion: 0.397059
#  Steps taken: 272
#  Cum regret: 0.419905
#  Accept proportion: 0.878187
#  Steps taken: 353
#  Cum regret: 0.291551
#  Accept proportion: 0.975610
#  Steps taken: 205
#  Cum regret: 0.106959
# Experiment: Step 1
#  Accept proportion: 0.000000
#  Steps taken: 186
#  Cum regret: 0.385008
#  Accept proportion: 0.000000
#  Steps taken: 354
#  Cum regret: 0.609487
#  Accept proportion: 0.583333
#  Steps taken: 360
#  Cum regret: 0.561444
#  Accept proportion: 0.923695
#  Steps taken: 249
#  Cum regret: 1.222252
# ...

# %%
plot_results(results)
cum_regrets
# Out:
# <ggplot: (8766438433493)>
# <ggplot: (8766397296117)>
# [396.00165396304556,
#  31.796363984401324,
#  38.19703471246681,
#  37.986624965243976,
#  40.24901412474341]

# %%
def make_mala(eta0):
    return MalaTS(num_articles, dim1, [0]*(dim1), cov=None, 
                                     step_size=lambda t: eta0/(1 + t * np.sqrt(sparsity/dim)), n_steps=9999,
                                     time = time_limit,
                                     init_pt=None, verbosity=2)
agents2 = [make_mala(eta0) for eta0 in [2.0,1.0]]
results2, cum_regrets2 = simple_compare(agents2, num_articles, dim, sparsity, 10, seed, verbosity=1, dist_type='Bernoulli')
plot_results(results2)
# Out:
# theta [ 1.62434536 -0.61175641 -0.52817175 -1.07296862  0.86540763 -2.3015387
#   1.74481176 -0.7612069   0.3190391  -0.24937038  1.46210794 -2.06014071
#  -0.3224172  -0.38405435  1.13376944 -1.09989127 -0.17242821 -0.87785842
#   0.04221375  0.58281521 -1.10061918]
# Experiment: Step 0
#  Sample: array([ -8.62158681,  16.04521768,  36.21718195, -32.21223896,
#        -56.7632536 ,   5.96407805, -32.6766855 ,  47.95695776,
#        -29.07582432,   7.92585488,  -3.23598955, -21.24549521,
#        -38.29103759,  19.85261994, -32.3773518 , -14.67840884,
#         43.74764355,   5.88467095,  -0.60028814,  87.27402768,
#          4.02642036])
#  Accept proportion: 1.000000
#  Steps taken: 206
#  Cum regret: 0.847812
#  Sample: array([-0.17809044, -0.70734583, -1.62858611,  0.80944162,  1.64493087,
#         0.50609988,  0.00769485, -0.34041253, -1.46325371, -1.44508293,
#         2.14795681, -0.41477741, -1.98223537, -0.96549164,  1.41653286,
# ...
