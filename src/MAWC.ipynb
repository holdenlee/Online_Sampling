# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import importlib
import os
import sys

from base.experiment import *
from logistic.env_logistic import *
from logistic.agent_logistic import *
from utils import *
from compare_utils import *
from agents import *

import copy
import numpy as np
import math
import matplotlib.pyplot as plt
import numpy.linalg as npla
import scipy.linalg as spla
import pickle
import pandas as pd
import plotnine as gg
import warnings
warnings.filterwarnings('ignore')


#https://www.tutorialspoint.com/python/python_command_line_arguments.htm
#print 'Number of arguments:', len(sys.argv), 'arguments.'
#print 'Argument List:', str(sys.argv)
time=0.1
T=1000
name='../outputs/ma/wc'
seed=201
num_articles = 1
dim = 20
dim1 = dim+1
sparsity = 5.0
verbosity=1
batch_size = 64
agents = make_shortlist_agents(num_articles, dim, sparsity, time, verbosity=verbosity, batch_size=batch_size)
mala_agent = MalaTS(num_articles, dim1, [0]*dim1, cov=None, 
                                             step_size=lambda t: 0.5/(1 + t * np.sqrt(sparsity/dim)), time=time, n_steps=9999,
                                             init_pt=None, verbosity=verbosity, leapfrog = True)
"""['mala_lf',
                    'online_laplace',
                    'pg',
                    'sgld',
                    'sagald',
                    'prec_sagald']"""
agents = [mala_agent]+agents
results = simple_compare(agents, num_articles, dim, sparsity, T, seed, verbosity=1)
agents_info = [agents[0].theta,
               (agents[1].est_coeffs, agents[1].est_inv_vars),
               agents[3].theta,
               (agents[4].theta, agents[4].gradient, agents[4].gradients),
               (agents[5].theta, agents[5].gradient, agents[5].gradients, agents[5].weights)]
pickle.dump(agents_info, open('%s_agents.p' % name,'wb'))
data = (agents[0].contexts,agents[0].rewards)
pickle.dump(data, open('%s_data.p' % name,'wb'))        
samples_list = []
agent0 = copy.deepcopy(agents[0])
agent0.v=1
agent0.time=0
agent0.n_steps=1000
agents = [agent0] + agents
for agent in agents:
    samples = redraw_samples(agent, 1000, 2)
    samples_list += [samples]
samples_list = np.asarray(samples_list)
pickle.dump(samples_list, open('%s.p' % name,'wb'))
print(merr(samples_list, 0.25))

# '../outputs/ma1.p'
# Out:
# theta [ 2.70684984  0.62813271  0.90796945  0.50382575  0.65111795 -0.31931804
#  -0.84807698  0.60596535 -2.01816824  0.74012206  0.52881349 -0.58900053
#   0.18869531 -0.75887206 -0.93323722  0.95505651  0.19079432  1.97875732
#   2.60596728  0.68350889  0.30266545]
# Experiment: Step 0
#  Accept proportion: 0.395894
#  Steps taken: 341
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 0
#  Cum regret: 0.000000
#  Steps taken: 0
#  Cum regret: 0.000000
#  Steps taken: 0
#  Cum regret: 0.000000
# Experiment: Step 1
#  Accept proportion: 0.610644
#  Steps taken: 357
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 352
#  Cum regret: 0.000000
#  Steps taken: 1148
#  Cum regret: 0.000000
#  Steps taken: 1352
#  Cum regret: 0.000000
#  Steps taken: 304
#  Cum regret: 0.000000
# Experiment: Step 2
#  Accept proportion: 0.768786
#  Steps taken: 346
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 337
#  Cum regret: 0.000000
#  Steps taken: 1094
#  Cum regret: 0.000000
#  Steps taken: 876
#  Cum regret: 0.000000
#  Steps taken: 292
#  Cum regret: 0.000000
# Experiment: Step 3
#  Accept proportion: 0.832853
#  Steps taken: 347
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 354
#  Cum regret: 0.000000
#  Steps taken: 1100
#  Cum regret: 0.000000
#  Steps taken: 1283
#  Cum regret: 0.000000
#  Steps taken: 261
#  Cum regret: 0.000000
# Experiment: Step 4
#  Accept proportion: 0.873874
#  Steps taken: 222
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 337
#  Cum regret: 0.000000
#  Steps taken: 1057
#  Cum regret: 0.000000
#  Steps taken: 1246
#  Cum regret: 0.000000
#  Steps taken: 194
#  Cum regret: 0.000000
# Experiment: Step 5
#  Accept proportion: 0.886628
#  Steps taken: 344
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 275
#  Cum regret: 0.000000
#  Steps taken: 1040
#  Cum regret: 0.000000
#  Steps taken: 1261
#  Cum regret: 0.000000
#  Steps taken: 273
#  Cum regret: 0.000000
# Experiment: Step 6
#  Accept proportion: 0.911681
#  Steps taken: 351
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 350
#  Cum regret: 0.000000
#  Steps taken: 1044
#  Cum regret: 0.000000
#  Steps taken: 1121
#  Cum regret: 0.000000
#  Steps taken: 186
#  Cum regret: 0.000000
# Experiment: Step 7
#  Accept proportion: 0.928144
#  Steps taken: 334
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 242
#  Cum regret: 0.000000
#  Steps taken: 706
#  Cum regret: 0.000000
#  Steps taken: 1108
#  Cum regret: 0.000000
#  Steps taken: 230
#  Cum regret: 0.000000
# Experiment: Step 8
#  Accept proportion: 0.857798
#  Steps taken: 218
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 230
#  Cum regret: 0.000000
#  Steps taken: 694
#  Cum regret: 0.000000
#  Steps taken: 1058
#  Cum regret: 0.000000
#  Steps taken: 162
#  Cum regret: 0.000000
# Experiment: Step 9
#  Accept proportion: 0.917683
#  Steps taken: 328
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 255
#  Cum regret: 0.000000
#  Steps taken: 800
#  Cum regret: 0.000000
#  Steps taken: 858
#  Cum regret: 0.000000
#  Steps taken: 146
#  Cum regret: 0.000000
# Experiment: Step 10
#  Accept proportion: 0.900685
#  Steps taken: 292
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 223
#  Cum regret: 0.000000
#  Steps taken: 627
#  Cum regret: 0.000000
#  Steps taken: 1070
#  Cum regret: 0.000000
#  Steps taken: 124
#  Cum regret: 0.000000
# Experiment: Step 11
#  Accept proportion: 0.921212
#  Steps taken: 330
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 318
#  Cum regret: 0.000000
#  Steps taken: 766
#  Cum regret: 0.000000
#  Steps taken: 1194
#  Cum regret: 0.000000
#  Steps taken: 162
#  Cum regret: 0.000000
# Experiment: Step 12
#  Accept proportion: 0.930818
#  Steps taken: 318
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 348
#  Cum regret: 0.000000
#  Steps taken: 769
#  Cum regret: 0.000000
#  Steps taken: 1217
#  Cum regret: 0.000000
#  Steps taken: 230
#  Cum regret: 0.000000
# Experiment: Step 13
#  Accept proportion: 0.927052
#  Steps taken: 329
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 337
#  Cum regret: 0.000000
#  Steps taken: 1051
#  Cum regret: 0.000000
#  Steps taken: 1186
#  Cum regret: 0.000000
#  Steps taken: 150
#  Cum regret: 0.000000
# Experiment: Step 14
#  Accept proportion: 0.930723
#  Steps taken: 332
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 240
#  Cum regret: 0.000000
#  Steps taken: 1005
#  Cum regret: 0.000000
#  Steps taken: 1064
#  Cum regret: 0.000000
#  Steps taken: 117
#  Cum regret: 0.000000
# Experiment: Step 15
#  Accept proportion: 0.900958
#  Steps taken: 313
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 250
#  Cum regret: 0.000000
#  Steps taken: 675
#  Cum regret: 0.000000
#  Steps taken: 1148
#  Cum regret: 0.000000
#  Steps taken: 147
#  Cum regret: 0.000000
# Experiment: Step 16
#  Accept proportion: 0.953488
#  Steps taken: 215
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 250
#  Cum regret: 0.000000
#  Steps taken: 693
#  Cum regret: 0.000000
#  Steps taken: 1168
#  Cum regret: 0.000000
#  Steps taken: 145
#  Cum regret: 0.000000
# Experiment: Step 17
#  Accept proportion: 0.952756
#  Steps taken: 254
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 341
#  Cum regret: 0.000000
#  Steps taken: 595
#  Cum regret: 0.000000
#  Steps taken: 1028
#  Cum regret: 0.000000
#  Steps taken: 120
#  Cum regret: 0.000000
# Experiment: Step 18
#  Accept proportion: 0.945578
#  Steps taken: 294
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 246
#  Cum regret: 0.000000
#  Steps taken: 642
#  Cum regret: 0.000000
#  Steps taken: 1169
#  Cum regret: 0.000000
#  Steps taken: 137
#  Cum regret: 0.000000
# Experiment: Step 19
#  Accept proportion: 0.942238
#  Steps taken: 277
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 241
#  Cum regret: 0.000000
#  Steps taken: 684
#  Cum regret: 0.000000
#  Steps taken: 1157
#  Cum regret: 0.000000
#  Steps taken: 131
#  Cum regret: 0.000000
# Experiment: Step 20
#  Accept proportion: 0.958580
#  Steps taken: 338
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 250
#  Cum regret: 0.000000
#  Steps taken: 666
#  Cum regret: 0.000000
#  Steps taken: 1014
#  Cum regret: 0.000000
#  Steps taken: 111
#  Cum regret: 0.000000
# Experiment: Step 21
#  Accept proportion: 0.939068
#  Steps taken: 279
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 223
#  Cum regret: 0.000000
#  Steps taken: 585
#  Cum regret: 0.000000
#  Steps taken: 1021
#  Cum regret: 0.000000
#  Steps taken: 117
#  Cum regret: 0.000000
# Experiment: Step 22
#  Accept proportion: 0.927052
#  Steps taken: 329
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 248
#  Cum regret: 0.000000
#  Steps taken: 596
#  Cum regret: 0.000000
#  Steps taken: 1002
#  Cum regret: 0.000000
#  Steps taken: 109
#  Cum regret: 0.000000
# Experiment: Step 23
#  Accept proportion: 0.963100
#  Steps taken: 271
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 227
#  Cum regret: 0.000000
#  Steps taken: 659
#  Cum regret: 0.000000
#  Steps taken: 1133
#  Cum regret: 0.000000
#  Steps taken: 127
#  Cum regret: 0.000000
# Experiment: Step 24
#  Accept proportion: 0.947692
#  Steps taken: 325
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 234
#  Cum regret: 0.000000
#  Steps taken: 577
#  Cum regret: 0.000000
#  Steps taken: 984
#  Cum regret: 0.000000
#  Steps taken: 113
#  Cum regret: 0.000000
# Experiment: Step 25
#  Accept proportion: 0.967638
#  Steps taken: 309
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 335
#  Cum regret: 0.000000
#  Steps taken: 728
#  Cum regret: 0.000000
#  Steps taken: 1209
#  Cum regret: 0.000000
#  Steps taken: 191
#  Cum regret: 0.000000
# Experiment: Step 26
#  Accept proportion: 0.970149
#  Steps taken: 268
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 215
#  Cum regret: 0.000000
#  Steps taken: 546
#  Cum regret: 0.000000
#  Steps taken: 974
#  Cum regret: 0.000000
#  Steps taken: 93
#  Cum regret: 0.000000
# Experiment: Step 27
#  Accept proportion: 0.958175
#  Steps taken: 263
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 215
#  Cum regret: 0.000000
#  Steps taken: 538
#  Cum regret: 0.000000
#  Steps taken: 893
#  Cum regret: 0.000000
#  Steps taken: 76
#  Cum regret: 0.000000
# Experiment: Step 28
#  Accept proportion: 0.966292
#  Steps taken: 267
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 215
#  Cum regret: 0.000000
#  Steps taken: 614
#  Cum regret: 0.000000
#  Steps taken: 966
#  Cum regret: 0.000000
#  Steps taken: 78
#  Cum regret: 0.000000
# Experiment: Step 29
#  Accept proportion: 0.981273
#  Steps taken: 267
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 205
#  Cum regret: 0.000000
#  Steps taken: 548
#  Cum regret: 0.000000
#  Steps taken: 974
#  Cum regret: 0.000000
#  Steps taken: 105
#  Cum regret: 0.000000
# Experiment: Step 30
#  Accept proportion: 0.963370
#  Steps taken: 273
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 202
#  Cum regret: 0.000000
#  Steps taken: 605
#  Cum regret: 0.000000
#  Steps taken: 1084
#  Cum regret: 0.000000
#  Steps taken: 129
#  Cum regret: 0.000000
# Experiment: Step 31
#  Accept proportion: 0.983108
#  Steps taken: 296
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 239
#  Cum regret: 0.000000
#  Steps taken: 623
#  Cum regret: 0.000000
#  Steps taken: 1107
#  Cum regret: 0.000000
#  Steps taken: 129
#  Cum regret: 0.000000
# Experiment: Step 32
#  Accept proportion: 0.978022
#  Steps taken: 182
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 190
#  Cum regret: 0.000000
#  Steps taken: 698
#  Cum regret: 0.000000
#  Steps taken: 976
#  Cum regret: 0.000000
#  Steps taken: 101
#  Cum regret: 0.000000
# Experiment: Step 33
#  Accept proportion: 0.977049
#  Steps taken: 305
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 241
#  Cum regret: 0.000000
#  Steps taken: 561
#  Cum regret: 0.000000
#  Steps taken: 953
#  Cum regret: 0.000000
#  Steps taken: 113
#  Cum regret: 0.000000
# Experiment: Step 34
#  Accept proportion: 0.981481
#  Steps taken: 270
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 219
#  Cum regret: 0.000000
#  Steps taken: 629
#  Cum regret: 0.000000
#  Steps taken: 1077
#  Cum regret: 0.000000
#  Steps taken: 129
#  Cum regret: 0.000000
# Experiment: Step 35
#  Accept proportion: 0.960784
#  Steps taken: 306
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 238
#  Cum regret: 0.000000
#  Steps taken: 540
#  Cum regret: 0.000000
#  Steps taken: 925
#  Cum regret: 0.000000
#  Steps taken: 121
#  Cum regret: 0.000000
# Experiment: Step 36
#  Accept proportion: 0.984436
#  Steps taken: 257
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 207
#  Cum regret: 0.000000
#  Steps taken: 603
#  Cum regret: 0.000000
#  Steps taken: 905
#  Cum regret: 0.000000
#  Steps taken: 186
#  Cum regret: 0.000000
# Experiment: Step 37
#  Accept proportion: 0.984436
#  Steps taken: 257
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 307
#  Cum regret: 0.000000
#  Steps taken: 660
#  Cum regret: 0.000000
#  Steps taken: 626
#  Cum regret: 0.000000
#  Steps taken: 110
#  Cum regret: 0.000000
# Experiment: Step 38
#  Accept proportion: 0.981061
#  Steps taken: 264
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 200
#  Cum regret: 0.000000
#  Steps taken: 539
#  Cum regret: 0.000000
#  Steps taken: 894
#  Cum regret: 0.000000
#  Steps taken: 90
#  Cum regret: 0.000000
# Experiment: Step 39
#  Accept proportion: 0.968872
#  Steps taken: 257
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 207
#  Cum regret: 0.000000
#  Steps taken: 526
#  Cum regret: 0.000000
#  Steps taken: 896
#  Cum regret: 0.000000
#  Steps taken: 115
#  Cum regret: 0.000000
# Experiment: Step 40
#  Accept proportion: 0.969466
#  Steps taken: 262
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 229
#  Cum regret: 0.000000
#  Steps taken: 612
#  Cum regret: 0.000000
#  Steps taken: 1032
#  Cum regret: 0.000000
#  Steps taken: 137
#  Cum regret: 0.000000
# Experiment: Step 41
#  Accept proportion: 0.961089
#  Steps taken: 257
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 267
#  Cum regret: 0.000000
#  Steps taken: 767
#  Cum regret: 0.000000
#  Steps taken: 943
#  Cum regret: 0.000000
#  Steps taken: 170
#  Cum regret: 0.000000
# Experiment: Step 42
#  Accept proportion: 0.992509
#  Steps taken: 267
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 211
#  Cum regret: 0.000000
#  Steps taken: 731
#  Cum regret: 0.000000
#  Steps taken: 1048
#  Cum regret: 0.000000
#  Steps taken: 197
#  Cum regret: 0.000000
# Experiment: Step 43
#  Accept proportion: 0.977419
#  Steps taken: 310
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 232
#  Cum regret: 0.000000
#  Steps taken: 548
#  Cum regret: 0.000000
#  Steps taken: 1043
#  Cum regret: 0.000000
#  Steps taken: 128
#  Cum regret: 0.000000
# Experiment: Step 44
#  Accept proportion: 0.977049
#  Steps taken: 305
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 227
#  Cum regret: 0.000000
#  Steps taken: 446
#  Cum regret: 0.000000
#  Steps taken: 814
#  Cum regret: 0.000000
#  Steps taken: 163
#  Cum regret: 0.000000
# Experiment: Step 45
#  Accept proportion: 0.969298
#  Steps taken: 228
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 285
#  Cum regret: 0.000000
#  Steps taken: 787
#  Cum regret: 0.000000
#  Steps taken: 926
#  Cum regret: 0.000000
#  Steps taken: 121
#  Cum regret: 0.000000
# Experiment: Step 46
#  Accept proportion: 0.984436
#  Steps taken: 257
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 206
#  Cum regret: 0.000000
#  Steps taken: 501
#  Cum regret: 0.000000
#  Steps taken: 903
#  Cum regret: 0.000000
#  Steps taken: 184
#  Cum regret: 0.000000
# Experiment: Step 47
#  Accept proportion: 0.973684
#  Steps taken: 266
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 299
#  Cum regret: 0.000000
#  Steps taken: 684
#  Cum regret: 0.000000
#  Steps taken: 891
#  Cum regret: 0.000000
#  Steps taken: 120
#  Cum regret: 0.000000
# Experiment: Step 48
#  Accept proportion: 0.977612
#  Steps taken: 268
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 296
#  Cum regret: 0.000000
#  Steps taken: 535
#  Cum regret: 0.000000
#  Steps taken: 881
#  Cum regret: 0.000000
#  Steps taken: 127
#  Cum regret: 0.000000
# Experiment: Step 49
#  Accept proportion: 0.972549
#  Steps taken: 255
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 297
#  Cum regret: 0.000000
#  Steps taken: 493
#  Cum regret: 0.000000
#  Steps taken: 869
#  Cum regret: 0.000000
#  Steps taken: 121
#  Cum regret: 0.000000
# Experiment: Step 50
#  Accept proportion: 0.952000
#  Steps taken: 250
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 205
#  Cum regret: 0.000000
#  Steps taken: 495
#  Cum regret: 0.000000
#  Steps taken: 870
#  Cum regret: 0.000000
#  Steps taken: 129
#  Cum regret: 0.000000
# Experiment: Step 51
#  Accept proportion: 0.967391
#  Steps taken: 184
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 191
#  Cum regret: 0.000000
#  Steps taken: 506
#  Cum regret: 0.000000
#  Steps taken: 887
#  Cum regret: 0.000000
#  Steps taken: 109
#  Cum regret: 0.000000
# Experiment: Step 52
#  Accept proportion: 0.972973
#  Steps taken: 259
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 207
#  Cum regret: 0.000000
#  Steps taken: 584
#  Cum regret: 0.000000
#  Steps taken: 992
#  Cum regret: 0.000000
#  Steps taken: 130
#  Cum regret: 0.000000
# Experiment: Step 53
#  Accept proportion: 0.982332
#  Steps taken: 283
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 230
#  Cum regret: 0.000000
#  Steps taken: 571
#  Cum regret: 0.000000
#  Steps taken: 970
#  Cum regret: 0.000000
#  Steps taken: 128
#  Cum regret: 0.000000
# Experiment: Step 54
#  Accept proportion: 0.979310
#  Steps taken: 290
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 221
#  Cum regret: 0.000000
#  Steps taken: 570
#  Cum regret: 0.000000
#  Steps taken: 985
#  Cum regret: 0.000000
#  Steps taken: 127
#  Cum regret: 0.000000
# Experiment: Step 55
#  Accept proportion: 0.996479
#  Steps taken: 284
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 226
#  Cum regret: 0.000000
#  Steps taken: 561
#  Cum regret: 0.000000
#  Steps taken: 969
#  Cum regret: 0.000000
#  Steps taken: 130
#  Cum regret: 0.000000
# Experiment: Step 56
#  Accept proportion: 0.985915
#  Steps taken: 284
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 46
#  Cum regret: 0.000000
#  Steps taken: 284
#  Cum regret: 0.000000
#  Steps taken: 967
#  Cum regret: 0.000000
#  Steps taken: 127
#  Cum regret: 0.000000
# Experiment: Step 57
#  Accept proportion: 0.971326
#  Steps taken: 279
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 27
#  Cum regret: 0.000000
#  Steps taken: 187
#  Cum regret: 0.000000
#  Steps taken: 875
#  Cum regret: 0.000000
#  Steps taken: 106
#  Cum regret: 0.000000
# Experiment: Step 58
#  Accept proportion: 1.000000
#  Steps taken: 171
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 167
#  Cum regret: 0.000000
#  Steps taken: 559
#  Cum regret: 0.000000
#  Steps taken: 940
#  Cum regret: 0.000000
#  Steps taken: 23
#  Cum regret: 0.000000
# Experiment: Step 59
#  Accept proportion: 0.982206
#  Steps taken: 281
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 111
#  Cum regret: 0.000000
#  Steps taken: 482
#  Cum regret: 0.000000
#  Steps taken: 845
#  Cum regret: 0.000000
#  Steps taken: 15
#  Cum regret: 0.000000
# Experiment: Step 60
#  Accept proportion: 0.969388
#  Steps taken: 196
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 179
#  Cum regret: 0.000000
#  Steps taken: 486
#  Cum regret: 0.000000
#  Steps taken: 832
#  Cum regret: 0.000000
#  Steps taken: 113
#  Cum regret: 0.000000
# Experiment: Step 61
#  Accept proportion: 0.994565
#  Steps taken: 184
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 219
#  Cum regret: 0.000000
#  Steps taken: 461
#  Cum regret: 0.000000
#  Steps taken: 780
#  Cum regret: 0.000000
#  Steps taken: 164
#  Cum regret: 0.000000
# Experiment: Step 62
#  Accept proportion: 0.976096
#  Steps taken: 251
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 166
#  Cum regret: 0.000000
#  Steps taken: 474
#  Cum regret: 0.000000
#  Steps taken: 813
#  Cum regret: 0.000000
#  Steps taken: 110
#  Cum regret: 0.000000
# Experiment: Step 63
#  Accept proportion: 0.987552
#  Steps taken: 241
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 90
#  Cum regret: 0.000000
#  Steps taken: 258
#  Cum regret: 0.000000
#  Steps taken: 993
#  Cum regret: 0.000000
#  Steps taken: 126
#  Cum regret: 0.000000
# Experiment: Step 64
#  Accept proportion: 0.994536
#  Steps taken: 183
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 113
#  Cum regret: 0.000000
#  Steps taken: 766
#  Cum regret: 0.000000
#  Steps taken: 939
#  Cum regret: 0.000000
#  Steps taken: 109
#  Cum regret: 0.000000
# Experiment: Step 65
#  Accept proportion: 0.978541
#  Steps taken: 233
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 73
#  Cum regret: 0.000000
#  Steps taken: 364
#  Cum regret: 0.000000
#  Steps taken: 446
#  Cum regret: 0.000000
#  Steps taken: 90
#  Cum regret: 0.000000
# Experiment: Step 66
#  Accept proportion: 0.979592
#  Steps taken: 245
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 187
#  Cum regret: 0.000000
#  Steps taken: 373
#  Cum regret: 0.000000
#  Steps taken: 465
#  Cum regret: 0.000000
#  Steps taken: 30
#  Cum regret: 0.000000
# Experiment: Step 67
#  Accept proportion: 0.978571
#  Steps taken: 280
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 219
#  Cum regret: 0.000000
#  Steps taken: 418
#  Cum regret: 0.000000
#  Steps taken: 507
#  Cum regret: 0.000000
#  Steps taken: 35
#  Cum regret: 0.000000
# Experiment: Step 68
#  Accept proportion: 0.979522
#  Steps taken: 293
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 67
#  Cum regret: 0.000000
#  Steps taken: 185
#  Cum regret: 0.000000
#  Steps taken: 439
#  Cum regret: 0.000000
#  Steps taken: 68
#  Cum regret: 0.000000
# Experiment: Step 69
#  Accept proportion: 0.953191
#  Steps taken: 235
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 192
#  Cum regret: 0.000000
#  Steps taken: 350
#  Cum regret: 0.000000
#  Steps taken: 434
#  Cum regret: 0.000000
#  Steps taken: 92
#  Cum regret: 0.000000
# Experiment: Step 70
#  Accept proportion: 0.979339
#  Steps taken: 242
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 191
#  Cum regret: 0.000000
#  Steps taken: 421
#  Cum regret: 0.000000
#  Steps taken: 391
#  Cum regret: 0.000000
#  Steps taken: 100
#  Cum regret: 0.000000
# Experiment: Step 71
#  Accept proportion: 0.986667
#  Steps taken: 225
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 28
#  Cum regret: 0.000000
#  Steps taken: 111
#  Cum regret: 0.000000
#  Steps taken: 517
#  Cum regret: 0.000000
#  Steps taken: 105
#  Cum regret: 0.000000
# Experiment: Step 72
#  Accept proportion: 0.984127
#  Steps taken: 189
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 36
#  Cum regret: 0.000000
#  Steps taken: 222
#  Cum regret: 0.000000
#  Steps taken: 502
#  Cum regret: 0.000000
#  Steps taken: 106
#  Cum regret: 0.000000
# Experiment: Step 73
#  Accept proportion: 0.988636
#  Steps taken: 264
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 150
#  Cum regret: 0.000000
#  Steps taken: 560
#  Cum regret: 0.000000
#  Steps taken: 444
#  Cum regret: 0.000000
#  Steps taken: 98
#  Cum regret: 0.000000
# Experiment: Step 74
#  Accept proportion: 0.980263
#  Steps taken: 152
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 196
#  Cum regret: 0.000000
#  Steps taken: 553
#  Cum regret: 0.000000
#  Steps taken: 542
#  Cum regret: 0.000000
#  Steps taken: 154
#  Cum regret: 0.000000
# Experiment: Step 75
#  Accept proportion: 0.989071
#  Steps taken: 183
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 171
#  Cum regret: 0.000000
#  Steps taken: 350
#  Cum regret: 0.000000
#  Steps taken: 433
#  Cum regret: 0.000000
#  Steps taken: 43
#  Cum regret: 0.000000
# Experiment: Step 76
#  Accept proportion: 0.986239
#  Steps taken: 218
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 262
#  Cum regret: 0.000000
#  Steps taken: 521
#  Cum regret: 0.000000
#  Steps taken: 390
#  Cum regret: 0.000000
#  Steps taken: 29
#  Cum regret: 0.000000
# Experiment: Step 77
#  Accept proportion: 0.986667
#  Steps taken: 225
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 180
#  Cum regret: 0.000000
#  Steps taken: 466
#  Cum regret: 0.000000
#  Steps taken: 447
#  Cum regret: 0.000000
#  Steps taken: 98
#  Cum regret: 0.000000
# Experiment: Step 78
#  Accept proportion: 0.981343
#  Steps taken: 268
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 286
#  Cum regret: 0.000000
#  Steps taken: 426
#  Cum regret: 0.000000
#  Steps taken: 486
#  Cum regret: 0.000000
#  Steps taken: 76
#  Cum regret: 0.000000
# Experiment: Step 79
#  Accept proportion: 1.000000
#  Steps taken: 226
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 187
#  Cum regret: 0.000000
#  Steps taken: 348
#  Cum regret: 0.000000
#  Steps taken: 428
#  Cum regret: 0.000000
#  Steps taken: 31
#  Cum regret: 0.000000
# Experiment: Step 80
#  Accept proportion: 1.000000
#  Steps taken: 204
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 202
#  Cum regret: 0.000000
#  Steps taken: 420
#  Cum regret: 0.000000
#  Steps taken: 479
#  Cum regret: 0.000000
#  Steps taken: 65
#  Cum regret: 0.000000
# Experiment: Step 81
#  Accept proportion: 0.993590
#  Steps taken: 156
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 78
#  Cum regret: 0.000000
#  Steps taken: 204
#  Cum regret: 0.000000
#  Steps taken: 500
#  Cum regret: 0.000000
#  Steps taken: 102
#  Cum regret: 0.000000
# Experiment: Step 82
#  Accept proportion: 0.976471
#  Steps taken: 255
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 201
#  Cum regret: 0.000000
#  Steps taken: 409
#  Cum regret: 0.000000
#  Steps taken: 479
#  Cum regret: 0.000000
#  Steps taken: 75
#  Cum regret: 0.000000
# Experiment: Step 83
#  Accept proportion: 0.978873
#  Steps taken: 142
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 264
#  Cum regret: 0.000000
#  Steps taken: 405
#  Cum regret: 0.000000
#  Steps taken: 499
#  Cum regret: 0.000000
#  Steps taken: 101
#  Cum regret: 0.000000
# Experiment: Step 84
#  Accept proportion: 0.957198
#  Steps taken: 257
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 213
#  Cum regret: 0.000000
#  Steps taken: 424
#  Cum regret: 0.000000
#  Steps taken: 485
#  Cum regret: 0.000000
#  Steps taken: 67
#  Cum regret: 0.000000
# Experiment: Step 85
#  Accept proportion: 0.979452
#  Steps taken: 146
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 181
#  Cum regret: 0.000000
#  Steps taken: 348
#  Cum regret: 0.000000
#  Steps taken: 428
#  Cum regret: 0.000000
#  Steps taken: 87
#  Cum regret: 0.000000
# Experiment: Step 86
#  Accept proportion: 0.972789
#  Steps taken: 147
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 21
#  Cum regret: 0.000000
#  Steps taken: 332
#  Cum regret: 0.000000
#  Steps taken: 434
#  Cum regret: 0.000000
#  Steps taken: 89
#  Cum regret: 0.000000
# Experiment: Step 87
#  Accept proportion: 0.995370
#  Steps taken: 216
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 5
#  Cum regret: 0.000000
#  Steps taken: 180
#  Cum regret: 0.000000
#  Steps taken: 442
#  Cum regret: 0.000000
#  Steps taken: 99
#  Cum regret: 0.000000
# Experiment: Step 88
#  Accept proportion: 0.995968
#  Steps taken: 248
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 30
#  Cum regret: 0.000000
#  Steps taken: 246
#  Cum regret: 0.000000
#  Steps taken: 432
#  Cum regret: 0.000000
#  Steps taken: 90
#  Cum regret: 0.000000
# Experiment: Step 89
#  Accept proportion: 0.995192
#  Steps taken: 208
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 32
#  Cum regret: 0.000000
#  Steps taken: 369
#  Cum regret: 0.000000
#  Steps taken: 440
#  Cum regret: 0.000000
#  Steps taken: 69
#  Cum regret: 0.000000
# Experiment: Step 90
#  Accept proportion: 0.995000
#  Steps taken: 200
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 171
#  Cum regret: 0.000000
#  Steps taken: 371
#  Cum regret: 0.000000
#  Steps taken: 354
#  Cum regret: 0.000000
#  Steps taken: 8
#  Cum regret: 0.000000
# Experiment: Step 91
#  Accept proportion: 1.000000
#  Steps taken: 105
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 203
#  Cum regret: 0.000000
#  Steps taken: 421
#  Cum regret: 0.000000
#  Steps taken: 501
#  Cum regret: 0.000000
#  Steps taken: 94
#  Cum regret: 0.000000
# Experiment: Step 92
#  Accept proportion: 1.000000
#  Steps taken: 180
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 205
#  Cum regret: 0.000000
#  Steps taken: 530
#  Cum regret: 0.000000
#  Steps taken: 284
#  Cum regret: 0.000000
#  Steps taken: 100
#  Cum regret: 0.000000
# Experiment: Step 93
#  Accept proportion: 0.994709
#  Steps taken: 189
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 290
#  Cum regret: 0.000000
#  Steps taken: 600
#  Cum regret: 0.000000
#  Steps taken: 489
#  Cum regret: 0.000000
#  Steps taken: 33
#  Cum regret: 0.000000
# Experiment: Step 94
#  Accept proportion: 0.990000
#  Steps taken: 200
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 285
#  Cum regret: 0.000000
#  Steps taken: 432
#  Cum regret: 0.000000
#  Steps taken: 438
#  Cum regret: 0.000000
#  Steps taken: 8
#  Cum regret: 0.000000
# Experiment: Step 95
#  Accept proportion: 1.000000
#  Steps taken: 138
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 153
#  Cum regret: 0.000000
#  Steps taken: 366
#  Cum regret: 0.000000
#  Steps taken: 435
#  Cum regret: 0.000000
#  Steps taken: 77
#  Cum regret: 0.000000
# Experiment: Step 96
#  Accept proportion: 0.991416
#  Steps taken: 233
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 203
#  Cum regret: 0.000000
#  Steps taken: 626
#  Cum regret: 0.000000
#  Steps taken: 270
#  Cum regret: 0.000000
#  Steps taken: 97
#  Cum regret: 0.000000
# Experiment: Step 97
#  Accept proportion: 0.956522
#  Steps taken: 207
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 108
#  Cum regret: 0.000000
#  Steps taken: 275
#  Cum regret: 0.000000
#  Steps taken: 421
#  Cum regret: 0.000000
#  Steps taken: 99
#  Cum regret: 0.000000
# Experiment: Step 98
#  Accept proportion: 0.985981
#  Steps taken: 214
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 1
#  Cum regret: 0.000000
#  Steps taken: 493
#  Cum regret: 0.000000
#  Steps taken: 440
#  Cum regret: 0.000000
#  Steps taken: 136
#  Cum regret: 0.000000
# Experiment: Step 99
#  Accept proportion: 1.000000
#  Steps taken: 150
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 66
#  Cum regret: 0.000000
#  Steps taken: 613
#  Cum regret: 0.000000
#  Steps taken: 506
#  Cum regret: 0.000000
#  Steps taken: 131
#  Cum regret: 0.000000
# Experiment: Step 100
#  Accept proportion: 0.985714
#  Steps taken: 140
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 58
#  Cum regret: 0.000000
#  Steps taken: 368
#  Cum regret: 0.000000
#  Steps taken: 433
#  Cum regret: 0.000000
#  Steps taken: 63
#  Cum regret: 0.000000
# Experiment: Step 101
#  Accept proportion: 0.980583
#  Steps taken: 206
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 181
#  Cum regret: 0.000000
#  Steps taken: 364
#  Cum regret: 0.000000
#  Steps taken: 436
#  Cum regret: 0.000000
#  Steps taken: 89
#  Cum regret: 0.000000
# Experiment: Step 102
#  Accept proportion: 0.990385
#  Steps taken: 208
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 156
#  Cum regret: 0.000000
#  Steps taken: 571
#  Cum regret: 0.000000
#  Steps taken: 320
#  Cum regret: 0.000000
#  Steps taken: 63
#  Cum regret: 0.000000
# Experiment: Step 103
#  Accept proportion: 1.000000
#  Steps taken: 153
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 176
#  Cum regret: 0.000000
#  Steps taken: 500
#  Cum regret: 0.000000
#  Steps taken: 542
#  Cum regret: 0.000000
#  Steps taken: 76
#  Cum regret: 0.000000
# Experiment: Step 104
#  Accept proportion: 0.987578
#  Steps taken: 161
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 175
#  Cum regret: 0.000000
#  Steps taken: 404
#  Cum regret: 0.000000
#  Steps taken: 358
#  Cum regret: 0.000000
#  Steps taken: 18
#  Cum regret: 0.000000
# Experiment: Step 105
#  Accept proportion: 0.987879
#  Steps taken: 165
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 229
#  Cum regret: 0.000000
#  Steps taken: 330
#  Cum regret: 0.000000
#  Steps taken: 396
#  Cum regret: 0.000000
#  Steps taken: 56
#  Cum regret: 0.000000
# Experiment: Step 106
#  Accept proportion: 0.980583
#  Steps taken: 206
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 237
#  Cum regret: 0.000000
#  Steps taken: 368
#  Cum regret: 0.000000
#  Steps taken: 433
#  Cum regret: 0.000000
#  Steps taken: 43
#  Cum regret: 0.000000
# Experiment: Step 107
#  Accept proportion: 0.980100
#  Steps taken: 201
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 204
#  Cum regret: 0.000000
#  Steps taken: 413
#  Cum regret: 0.000000
#  Steps taken: 505
#  Cum regret: 0.000000
#  Steps taken: 99
#  Cum regret: 0.000000
# Experiment: Step 108
#  Accept proportion: 0.979920
#  Steps taken: 249
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 196
#  Cum regret: 0.000000
#  Steps taken: 425
#  Cum regret: 0.000000
#  Steps taken: 508
#  Cum regret: 0.000000
#  Steps taken: 104
#  Cum regret: 0.000000
# Experiment: Step 109
#  Accept proportion: 0.987013
#  Steps taken: 231
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 201
#  Cum regret: 0.000000
#  Steps taken: 422
#  Cum regret: 0.000000
#  Steps taken: 525
#  Cum regret: 0.000000
#  Steps taken: 100
#  Cum regret: 0.000000
# Experiment: Step 110
#  Accept proportion: 0.983402
#  Steps taken: 241
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 100
#  Cum regret: 0.000000
#  Steps taken: 369
#  Cum regret: 0.000000
#  Steps taken: 427
#  Cum regret: 0.000000
#  Steps taken: 90
#  Cum regret: 0.000000
# Experiment: Step 111
#  Accept proportion: 0.989744
#  Steps taken: 195
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 186
#  Cum regret: 0.000000
#  Steps taken: 365
#  Cum regret: 0.000000
#  Steps taken: 434
#  Cum regret: 0.000000
#  Steps taken: 90
#  Cum regret: 0.000000
# Experiment: Step 112
#  Accept proportion: 0.800000
#  Steps taken: 5
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 86
#  Cum regret: 0.000000
#  Steps taken: 287
#  Cum regret: 0.000000
#  Steps taken: 434
#  Cum regret: 0.000000
#  Steps taken: 92
#  Cum regret: 0.000000
# Experiment: Step 113
#  Accept proportion: 0.989362
#  Steps taken: 94
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 193
#  Cum regret: 0.000000
#  Steps taken: 461
#  Cum regret: 0.000000
#  Steps taken: 345
#  Cum regret: 0.000000
#  Steps taken: 86
#  Cum regret: 0.000000
# Experiment: Step 114
#  Accept proportion: 0.928571
#  Steps taken: 14
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 169
#  Cum regret: 0.000000
#  Steps taken: 371
#  Cum regret: 0.000000
#  Steps taken: 513
#  Cum regret: 0.000000
#  Steps taken: 107
#  Cum regret: 0.000000
# Experiment: Step 115
#  Accept proportion: 1.000000
#  Steps taken: 11
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 239
#  Cum regret: 0.000000
#  Steps taken: 546
#  Cum regret: 0.000000
#  Steps taken: 295
#  Cum regret: 0.000000
#  Steps taken: 99
#  Cum regret: 0.000000
# Experiment: Step 116
#  Accept proportion: 1.000000
#  Steps taken: 9
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 267
#  Cum regret: 0.000000
#  Steps taken: 504
#  Cum regret: 0.000000
#  Steps taken: 293
#  Cum regret: 0.000000
#  Steps taken: 45
#  Cum regret: 0.000000
# Experiment: Step 117
#  Accept proportion: 0.975000
#  Steps taken: 40
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 222
#  Cum regret: 0.000000
#  Steps taken: 460
#  Cum regret: 0.000000
#  Steps taken: 380
#  Cum regret: 0.000000
#  Steps taken: 15
#  Cum regret: 0.000000
# Experiment: Step 118
#  Accept proportion: 0.969231
#  Steps taken: 65
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 266
#  Cum regret: 0.000000
#  Steps taken: 443
#  Cum regret: 0.000000
#  Steps taken: 370
#  Cum regret: 0.000000
#  Steps taken: 60
#  Cum regret: 0.000000
# Experiment: Step 119
#  Accept proportion: 1.000000
#  Steps taken: 96
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 239
#  Cum regret: 0.000000
#  Steps taken: 444
#  Cum regret: 0.000000
#  Steps taken: 325
#  Cum regret: 0.000000
#  Steps taken: 52
#  Cum regret: 0.000000
# Experiment: Step 120
#  Accept proportion: 0.993902
#  Steps taken: 164
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 192
#  Cum regret: 0.000000
#  Steps taken: 434
#  Cum regret: 0.000000
#  Steps taken: 325
#  Cum regret: 0.000000
#  Steps taken: 68
#  Cum regret: 0.000000
# Experiment: Step 121
#  Accept proportion: 0.992593
#  Steps taken: 135
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 194
#  Cum regret: 0.000000
#  Steps taken: 592
#  Cum regret: 0.000000
#  Steps taken: 380
#  Cum regret: 0.000000
#  Steps taken: 156
#  Cum regret: 0.000000
# Experiment: Step 122
#  Accept proportion: 1.000000
#  Steps taken: 133
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 187
#  Cum regret: 0.000000
#  Steps taken: 583
#  Cum regret: 0.000000
#  Steps taken: 312
#  Cum regret: 0.000000
#  Steps taken: 91
#  Cum regret: 0.000000
# Experiment: Step 123
#  Accept proportion: 1.000000
#  Steps taken: 99
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 155
#  Cum regret: 0.000000
#  Steps taken: 417
#  Cum regret: 0.000000
#  Steps taken: 494
#  Cum regret: 0.000000
#  Steps taken: 104
#  Cum regret: 0.000000
# Experiment: Step 124
#  Accept proportion: 1.000000
#  Steps taken: 64
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 178
#  Cum regret: 0.000000
#  Steps taken: 467
#  Cum regret: 0.000000
#  Steps taken: 434
#  Cum regret: 0.000000
#  Steps taken: 160
#  Cum regret: 0.000000
# Experiment: Step 125
#  Accept proportion: 1.000000
#  Steps taken: 3
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 180
#  Cum regret: 0.000000
#  Steps taken: 399
#  Cum regret: 0.000000
#  Steps taken: 448
#  Cum regret: 0.000000
#  Steps taken: 160
#  Cum regret: 0.000000
# Experiment: Step 126
#  Accept proportion: 0.986014
#  Steps taken: 143
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 221
#  Cum regret: 0.000000
#  Steps taken: 420
#  Cum regret: 0.000000
#  Steps taken: 388
#  Cum regret: 0.000000
#  Steps taken: 162
#  Cum regret: 0.000000
# Experiment: Step 127
#  Accept proportion: 0.993827
#  Steps taken: 162
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 192
#  Cum regret: 0.000000
#  Steps taken: 579
#  Cum regret: 0.000000
#  Steps taken: 274
#  Cum regret: 0.000000
#  Steps taken: 137
#  Cum regret: 0.000000
# Experiment: Step 128
#  Accept proportion: 1.000000
#  Steps taken: 86
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 164
#  Cum regret: 0.000000
#  Steps taken: 514
#  Cum regret: 0.000000
#  Steps taken: 307
#  Cum regret: 0.000000
#  Steps taken: 132
#  Cum regret: 0.000000
# Experiment: Step 129
#  Accept proportion: 1.000000
#  Steps taken: 110
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 181
#  Cum regret: 0.000000
#  Steps taken: 492
#  Cum regret: 0.000000
#  Steps taken: 425
#  Cum regret: 0.000000
#  Steps taken: 160
#  Cum regret: 0.000000
# Experiment: Step 130
#  Accept proportion: 1.000000
#  Steps taken: 130
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 189
#  Cum regret: 0.000000
#  Steps taken: 420
#  Cum regret: 0.000000
#  Steps taken: 313
#  Cum regret: 0.000000
#  Steps taken: 161
#  Cum regret: 0.000000
# Experiment: Step 131
#  Accept proportion: 0.992481
#  Steps taken: 133
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 196
#  Cum regret: 0.000000
#  Steps taken: 599
#  Cum regret: 0.000000
#  Steps taken: 386
#  Cum regret: 0.000000
#  Steps taken: 163
#  Cum regret: 0.000000
# Experiment: Step 132
#  Accept proportion: 1.000000
#  Steps taken: 42
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 185
#  Cum regret: 0.000000
#  Steps taken: 542
#  Cum regret: 0.000000
#  Steps taken: 414
#  Cum regret: 0.000000
#  Steps taken: 106
#  Cum regret: 0.000000
# Experiment: Step 133
#  Accept proportion: 1.000000
#  Steps taken: 69
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 155
#  Cum regret: 0.000000
#  Steps taken: 409
#  Cum regret: 0.000000
#  Steps taken: 505
#  Cum regret: 0.000000
#  Steps taken: 105
#  Cum regret: 0.000000
# Experiment: Step 134
#  Accept proportion: 0.956522
#  Steps taken: 46
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 224
#  Cum regret: 0.000000
#  Steps taken: 373
#  Cum regret: 0.000000
#  Steps taken: 425
#  Cum regret: 0.000000
#  Steps taken: 92
#  Cum regret: 0.000000
# Experiment: Step 135
#  Accept proportion: 1.000000
#  Steps taken: 51
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 180
#  Cum regret: 0.000000
#  Steps taken: 420
#  Cum regret: 0.000000
#  Steps taken: 508
#  Cum regret: 0.000000
#  Steps taken: 104
#  Cum regret: 0.000000
# Experiment: Step 136
#  Accept proportion: 1.000000
#  Steps taken: 17
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 165
#  Cum regret: 0.000000
#  Steps taken: 584
#  Cum regret: 0.000000
#  Steps taken: 430
#  Cum regret: 0.000000
#  Steps taken: 123
#  Cum regret: 0.000000
# Experiment: Step 137
#  Accept proportion: 0.000000
#  Steps taken: 1
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 187
#  Cum regret: 0.000000
#  Steps taken: 420
#  Cum regret: 0.000000
#  Steps taken: 521
#  Cum regret: 0.000000
#  Steps taken: 55
#  Cum regret: 0.000000
# Experiment: Step 138
#  Accept proportion: 1.000000
#  Steps taken: 37
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 184
#  Cum regret: 0.000000
#  Steps taken: 556
#  Cum regret: 0.000000
#  Steps taken: 320
#  Cum regret: 0.000000
#  Steps taken: 19
#  Cum regret: 0.000000
# Experiment: Step 139
#  Accept proportion: 1.000000
#  Steps taken: 129
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 185
#  Cum regret: 0.000000
#  Steps taken: 424
#  Cum regret: 0.000000
#  Steps taken: 336
#  Cum regret: 0.000000
#  Steps taken: 9
#  Cum regret: 0.000000
# Experiment: Step 140
#  Accept proportion: 0.992593
#  Steps taken: 135
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 182
#  Cum regret: 0.000000
#  Steps taken: 592
#  Cum regret: 0.000000
#  Steps taken: 319
#  Cum regret: 0.000000
#  Steps taken: 13
#  Cum regret: 0.000000
# Experiment: Step 141
#  Accept proportion: 1.000000
#  Steps taken: 99
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 152
#  Cum regret: 0.000000
#  Steps taken: 408
#  Cum regret: 0.000000
#  Steps taken: 339
#  Cum regret: 0.000000
#  Steps taken: 109
#  Cum regret: 0.000000
# Experiment: Step 142
#  Accept proportion: 0.984962
#  Steps taken: 133
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 187
#  Cum regret: 0.000000
#  Steps taken: 483
#  Cum regret: 0.000000
#  Steps taken: 493
#  Cum regret: 0.000000
#  Steps taken: 114
#  Cum regret: 0.000000
# Experiment: Step 143
#  Accept proportion: 1.000000
#  Steps taken: 101
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 181
#  Cum regret: 0.000000
#  Steps taken: 408
#  Cum regret: 0.000000
#  Steps taken: 374
#  Cum regret: 0.000000
#  Steps taken: 157
#  Cum regret: 0.000000
# Experiment: Step 144
#  Accept proportion: 0.989583
#  Steps taken: 96
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 183
#  Cum regret: 0.000000
#  Steps taken: 514
#  Cum regret: 0.000000
#  Steps taken: 461
#  Cum regret: 0.000000
#  Steps taken: 97
#  Cum regret: 0.000000
# Experiment: Step 145
#  Accept proportion: 0.980583
#  Steps taken: 103
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 186
#  Cum regret: 0.000000
#  Steps taken: 639
#  Cum regret: 0.000000
#  Steps taken: 318
#  Cum regret: 0.000000
#  Steps taken: 89
#  Cum regret: 0.000000
# Experiment: Step 146
#  Accept proportion: 0.969697
#  Steps taken: 99
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 177
#  Cum regret: 0.000000
#  Steps taken: 497
#  Cum regret: 0.000000
#  Steps taken: 316
#  Cum regret: 0.000000
#  Steps taken: 108
#  Cum regret: 0.000000
# Experiment: Step 147
#  Accept proportion: 0.955556
#  Steps taken: 45
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 182
#  Cum regret: 0.000000
#  Steps taken: 442
#  Cum regret: 0.000000
#  Steps taken: 313
#  Cum regret: 0.000000
#  Steps taken: 89
#  Cum regret: 0.000000
# Experiment: Step 148
#  Accept proportion: 0.992308
#  Steps taken: 130
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 188
#  Cum regret: 0.000000
#  Steps taken: 416
#  Cum regret: 0.000000
#  Steps taken: 360
#  Cum regret: 0.000000
#  Steps taken: 148
#  Cum regret: 0.000000
# Experiment: Step 149
#  Accept proportion: 1.000000
#  Steps taken: 24
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 163
#  Cum regret: 0.000000
#  Steps taken: 408
#  Cum regret: 0.000000
#  Steps taken: 485
#  Cum regret: 0.000000
#  Steps taken: 111
#  Cum regret: 0.000000
# Experiment: Step 150
#  Accept proportion: 1.000000
#  Steps taken: 35
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 197
#  Cum regret: 0.000000
#  Steps taken: 561
#  Cum regret: 0.000000
#  Steps taken: 458
#  Cum regret: 0.000000
#  Steps taken: 152
#  Cum regret: 0.000000
# Experiment: Step 151
#  Accept proportion: 1.000000
#  Steps taken: 68
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 179
#  Cum regret: 0.000000
#  Steps taken: 412
#  Cum regret: 0.000000
#  Steps taken: 486
#  Cum regret: 0.000000
#  Steps taken: 103
#  Cum regret: 0.000000
# Experiment: Step 152
#  Accept proportion: 1.000000
#  Steps taken: 10
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 206
#  Cum regret: 0.000000
#  Steps taken: 650
#  Cum regret: 0.000000
#  Steps taken: 490
#  Cum regret: 0.000000
#  Steps taken: 156
#  Cum regret: 0.000000
# Experiment: Step 153
#  Accept proportion: 0.923077
#  Steps taken: 13
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 103
#  Cum regret: 0.000000
#  Steps taken: 646
#  Cum regret: 0.000000
#  Steps taken: 506
#  Cum regret: 0.000000
#  Steps taken: 114
#  Cum regret: 0.000000
# Experiment: Step 154
#  Accept proportion: 1.000000
#  Steps taken: 1
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 113
#  Cum regret: 0.000000
#  Steps taken: 421
#  Cum regret: 0.000000
#  Steps taken: 509
#  Cum regret: 0.000000
#  Steps taken: 104
#  Cum regret: 0.000000
# Experiment: Step 155
#  Accept proportion: 1.000000
#  Steps taken: 1
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 182
#  Cum regret: 0.000000
#  Steps taken: 448
#  Cum regret: 0.000000
#  Steps taken: 539
#  Cum regret: 0.000000
#  Steps taken: 136
#  Cum regret: 0.000000
# Experiment: Step 156
#  Accept proportion: 1.000000
#  Steps taken: 1
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 229
#  Cum regret: 0.000000
#  Steps taken: 448
#  Cum regret: 0.000000
#  Steps taken: 344
#  Cum regret: 0.000000
#  Steps taken: 95
#  Cum regret: 0.000000
# Experiment: Step 157
#  Accept proportion: 1.000000
#  Steps taken: 16
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 187
#  Cum regret: 0.000000
#  Steps taken: 584
#  Cum regret: 0.000000
#  Steps taken: 323
#  Cum regret: 0.000000
#  Steps taken: 43
#  Cum regret: 0.000000
# Experiment: Step 158
#  Accept proportion: 0.972222
#  Steps taken: 36
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 209
#  Cum regret: 0.000000
#  Steps taken: 481
#  Cum regret: 0.000000
#  Steps taken: 425
#  Cum regret: 0.000000
#  Steps taken: 135
#  Cum regret: 0.000000
# Experiment: Step 159
#  Accept proportion: 1.000000
#  Steps taken: 23
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 118
#  Cum regret: 0.000000
#  Steps taken: 389
#  Cum regret: 0.000000
#  Steps taken: 446
#  Cum regret: 0.000000
#  Steps taken: 99
#  Cum regret: 0.000000
# Experiment: Step 160
#  Accept proportion: 1.000000
#  Steps taken: 53
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 222
#  Cum regret: 0.000000
#  Steps taken: 423
#  Cum regret: 0.000000
#  Steps taken: 481
#  Cum regret: 0.000000
#  Steps taken: 65
#  Cum regret: 0.000000
# Experiment: Step 161
#  Accept proportion: 1.000000
#  Steps taken: 19
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 155
#  Cum regret: 0.000000
#  Steps taken: 369
#  Cum regret: 0.000000
#  Steps taken: 436
#  Cum regret: 0.000000
#  Steps taken: 75
#  Cum regret: 0.000000
# Experiment: Step 162
#  Accept proportion: 1.000000
#  Steps taken: 110
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 178
#  Cum regret: 0.000000
#  Steps taken: 416
#  Cum regret: 0.000000
#  Steps taken: 483
#  Cum regret: 0.000000
#  Steps taken: 80
#  Cum regret: 0.000000
# Experiment: Step 163
#  Accept proportion: 1.000000
#  Steps taken: 11
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 178
#  Cum regret: 0.000000
#  Steps taken: 592
#  Cum regret: 0.000000
#  Steps taken: 509
#  Cum regret: 0.000000
#  Steps taken: 102
#  Cum regret: 0.000000
# Experiment: Step 164
#  Accept proportion: 0.978723
#  Steps taken: 47
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 164
#  Cum regret: 0.000000
#  Steps taken: 572
#  Cum regret: 0.000000
#  Steps taken: 439
#  Cum regret: 0.000000
#  Steps taken: 118
#  Cum regret: 0.000000
# Experiment: Step 165
#  Accept proportion: 1.000000
#  Steps taken: 1
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 173
#  Cum regret: 0.000000
#  Steps taken: 417
#  Cum regret: 0.000000
#  Steps taken: 390
#  Cum regret: 0.000000
#  Steps taken: 3
#  Cum regret: 0.000000
# Experiment: Step 166
#  Accept proportion: 0.958333
#  Steps taken: 24
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 142
#  Cum regret: 0.000000
#  Steps taken: 564
#  Cum regret: 0.000000
#  Steps taken: 325
#  Cum regret: 0.000000
#  Steps taken: 23
#  Cum regret: 0.000000
# Experiment: Step 167
#  Accept proportion: 0.976190
#  Steps taken: 42
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 86
#  Cum regret: 0.000000
#  Steps taken: 476
#  Cum regret: 0.000000
#  Steps taken: 476
#  Cum regret: 0.000000
#  Steps taken: 76
#  Cum regret: 0.000000
# Experiment: Step 168
#  Accept proportion: 0.992308
#  Steps taken: 130
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 175
#  Cum regret: 0.000000
#  Steps taken: 531
#  Cum regret: 0.000000
#  Steps taken: 373
#  Cum regret: 0.000000
#  Steps taken: 11
#  Cum regret: 0.000000
# Experiment: Step 169
#  Accept proportion: 1.000000
#  Steps taken: 44
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 174
#  Cum regret: 0.000000
#  Steps taken: 482
#  Cum regret: 0.000000
#  Steps taken: 482
#  Cum regret: 0.000000
#  Steps taken: 104
#  Cum regret: 0.000000
# Experiment: Step 170
#  Accept proportion: 1.000000
#  Steps taken: 73
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 174
#  Cum regret: 0.000000
#  Steps taken: 418
#  Cum regret: 0.000000
#  Steps taken: 481
#  Cum regret: 0.000000
#  Steps taken: 106
#  Cum regret: 0.000000
# Experiment: Step 171
#  Accept proportion: 1.000000
#  Steps taken: 12
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 160
#  Cum regret: 0.000000
#  Steps taken: 536
#  Cum regret: 0.000000
#  Steps taken: 471
#  Cum regret: 0.000000
#  Steps taken: 158
#  Cum regret: 0.000000
# Experiment: Step 172
#  Accept proportion: 1.000000
#  Steps taken: 22
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 195
#  Cum regret: 0.000000
#  Steps taken: 438
#  Cum regret: 0.000000
#  Steps taken: 516
#  Cum regret: 0.000000
#  Steps taken: 105
#  Cum regret: 0.000000
# Experiment: Step 173
#  Accept proportion: 0.952381
#  Steps taken: 21
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 143
#  Cum regret: 0.000000
#  Steps taken: 460
#  Cum regret: 0.000000
#  Steps taken: 403
#  Cum regret: 0.000000
#  Steps taken: 96
#  Cum regret: 0.000000
# Experiment: Step 174
#  Accept proportion: 1.000000
#  Steps taken: 1
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 231
#  Cum regret: 0.000000
#  Steps taken: 645
#  Cum regret: 0.000000
#  Steps taken: 326
#  Cum regret: 0.000000
#  Steps taken: 114
#  Cum regret: 0.000000
# Experiment: Step 175
#  Accept proportion: 1.000000
#  Steps taken: 1
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 124
#  Cum regret: 0.000000
#  Steps taken: 422
#  Cum regret: 0.000000
#  Steps taken: 518
#  Cum regret: 0.000000
#  Steps taken: 106
#  Cum regret: 0.000000
# Experiment: Step 176
#  Accept proportion: 1.000000
#  Steps taken: 34
#  Cum regret: 0.000000
#  Cum regret: 0.000000
# ...
#  Cum regret: 0.000000
#  Steps taken: 366
#  Cum regret: 0.000000
#  Steps taken: 429
#  Cum regret: 0.000000
#  Steps taken: 63
#  Cum regret: 0.000000
# Experiment: Step 951
#  Accept proportion: 1.000000
#  Steps taken: 1
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 16
#  Cum regret: 0.000000
#  Steps taken: 95
#  Cum regret: 0.000000
#  Steps taken: 447
#  Cum regret: 0.000000
#  Steps taken: 110
#  Cum regret: 0.000000
# Experiment: Step 952
#  Accept proportion: 1.000000
#  Steps taken: 1
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 48
#  Cum regret: 0.000000
#  Steps taken: 91
#  Cum regret: 0.000000
#  Steps taken: 446
#  Cum regret: 0.000000
#  Steps taken: 102
#  Cum regret: 0.000000
# Experiment: Step 953
#  Accept proportion: 1.000000
#  Steps taken: 1
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 49
#  Cum regret: 0.000000
#  Steps taken: 363
#  Cum regret: 0.000000
#  Steps taken: 443
#  Cum regret: 0.000000
#  Steps taken: 126
#  Cum regret: 0.000000
# Experiment: Step 954
#  Accept proportion: 1.000000
#  Steps taken: 1
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 19
#  Cum regret: 0.000000
#  Steps taken: 372
#  Cum regret: 0.000000
#  Steps taken: 431
#  Cum regret: 0.000000
#  Steps taken: 123
#  Cum regret: 0.000000
# Experiment: Step 955
#  Accept proportion: 1.000000
#  Steps taken: 1
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 38
#  Cum regret: 0.000000
#  Steps taken: 90
#  Cum regret: 0.000000
#  Steps taken: 447
#  Cum regret: 0.000000
#  Steps taken: 131
#  Cum regret: 0.000000
# Experiment: Step 956
#  Accept proportion: 1.000000
#  Steps taken: 1
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 52
#  Cum regret: 0.000000
#  Steps taken: 325
#  Cum regret: 0.000000
#  Steps taken: 427
#  Cum regret: 0.000000
#  Steps taken: 91
#  Cum regret: 0.000000
# Experiment: Step 957
#  Accept proportion: 1.000000
#  Steps taken: 1
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 17
#  Cum regret: 0.000000
#  Steps taken: 274
#  Cum regret: 0.000000
#  Steps taken: 443
#  Cum regret: 0.000000
#  Steps taken: 56
#  Cum regret: 0.000000
# Experiment: Step 958
#  Accept proportion: 1.000000
#  Steps taken: 1
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 25
#  Cum regret: 0.000000
#  Steps taken: 79
#  Cum regret: 0.000000
#  Steps taken: 310
#  Cum regret: 0.000000
#  Steps taken: 1
#  Cum regret: 0.000000
# Experiment: Step 959
#  Accept proportion: 1.000000
#  Steps taken: 1
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 35
#  Cum regret: 0.000000
#  Steps taken: 448
#  Cum regret: 0.000000
#  Steps taken: 443
#  Cum regret: 0.000000
#  Steps taken: 2
#  Cum regret: 0.000000
# Experiment: Step 960
#  Accept proportion: 1.000000
#  Steps taken: 4
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 1
#  Cum regret: 0.000000
#  Steps taken: 480
#  Cum regret: 0.000000
#  Steps taken: 456
#  Cum regret: 0.000000
#  Steps taken: 140
#  Cum regret: 0.000000
# Experiment: Step 961
#  Accept proportion: 1.000000
#  Steps taken: 1
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 1
#  Cum regret: 0.000000
#  Steps taken: 411
#  Cum regret: 0.000000
#  Steps taken: 389
#  Cum regret: 0.000000
#  Steps taken: 20
#  Cum regret: 0.000000
# Experiment: Step 962
#  Accept proportion: 1.000000
#  Steps taken: 1
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 12
#  Cum regret: 0.000000
#  Steps taken: 88
#  Cum regret: 0.000000
#  Steps taken: 373
#  Cum regret: 0.000000
#  Steps taken: 76
#  Cum regret: 0.000000
# Experiment: Step 963
#  Accept proportion: 1.000000
#  Steps taken: 1
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 12
#  Cum regret: 0.000000
#  Steps taken: 93
#  Cum regret: 0.000000
#  Steps taken: 450
#  Cum regret: 0.000000
#  Steps taken: 148
#  Cum regret: 0.000000
# Experiment: Step 964
#  Accept proportion: 1.000000
#  Steps taken: 1
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 57
#  Cum regret: 0.000000
#  Steps taken: 367
#  Cum regret: 0.000000
#  Steps taken: 423
#  Cum regret: 0.000000
#  Steps taken: 3
#  Cum regret: 0.000000
# Experiment: Step 965
#  Accept proportion: 1.000000
#  Steps taken: 1
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 18
#  Cum regret: 0.000000
#  Steps taken: 251
#  Cum regret: 0.000000
#  Steps taken: 320
#  Cum regret: 0.000000
#  Steps taken: 1
#  Cum regret: 0.000000
# Experiment: Step 966
#  Accept proportion: 1.000000
#  Steps taken: 1
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 68
#  Cum regret: 0.000000
#  Steps taken: 339
#  Cum regret: 0.000000
#  Steps taken: 444
#  Cum regret: 0.000000
#  Steps taken: 149
#  Cum regret: 0.000000
# Experiment: Step 967
#  Accept proportion: 1.000000
#  Steps taken: 1
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 5
#  Cum regret: 0.000000
#  Steps taken: 301
#  Cum regret: 0.000000
#  Steps taken: 437
#  Cum regret: 0.000000
#  Steps taken: 50
#  Cum regret: 0.000000
# Experiment: Step 968
#  Accept proportion: 1.000000
#  Steps taken: 1
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 10
#  Cum regret: 0.000000
#  Steps taken: 76
#  Cum regret: 0.000000
#  Steps taken: 432
#  Cum regret: 0.000000
#  Steps taken: 100
#  Cum regret: 0.000000
# Experiment: Step 969
#  Accept proportion: 1.000000
#  Steps taken: 1
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 14
#  Cum regret: 0.000000
#  Steps taken: 89
#  Cum regret: 0.000000
#  Steps taken: 446
#  Cum regret: 0.000000
#  Steps taken: 147
#  Cum regret: 0.000000
# Experiment: Step 970
#  Accept proportion: 1.000000
#  Steps taken: 1
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 12
#  Cum regret: 0.000000
#  Steps taken: 85
#  Cum regret: 0.000000
#  Steps taken: 362
#  Cum regret: 0.000000
#  Steps taken: 119
#  Cum regret: 0.000000
# Experiment: Step 971
#  Accept proportion: 1.000000
#  Steps taken: 1
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 1
#  Cum regret: 0.000000
#  Steps taken: 465
#  Cum regret: 0.000000
#  Steps taken: 442
#  Cum regret: 0.000000
#  Steps taken: 1
#  Cum regret: 0.000000
# Experiment: Step 972
#  Accept proportion: 1.000000
#  Steps taken: 1
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 36
#  Cum regret: 0.000000
#  Steps taken: 146
#  Cum regret: 0.000000
#  Steps taken: 446
#  Cum regret: 0.000000
#  Steps taken: 151
#  Cum regret: 0.000000
# Experiment: Step 973
#  Accept proportion: 1.000000
#  Steps taken: 1
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 62
#  Cum regret: 0.000000
#  Steps taken: 315
#  Cum regret: 0.000000
#  Steps taken: 386
#  Cum regret: 0.000000
#  Steps taken: 5
#  Cum regret: 0.000000
# Experiment: Step 974
#  Accept proportion: 1.000000
#  Steps taken: 1
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 7
#  Cum regret: 0.000000
#  Steps taken: 92
#  Cum regret: 0.000000
#  Steps taken: 394
#  Cum regret: 0.000000
#  Steps taken: 148
#  Cum regret: 0.000000
# Experiment: Step 975
#  Accept proportion: 1.000000
#  Steps taken: 1
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 2
#  Cum regret: 0.000000
#  Steps taken: 157
#  Cum regret: 0.000000
#  Steps taken: 446
#  Cum regret: 0.000000
#  Steps taken: 61
#  Cum regret: 0.000000
# Experiment: Step 976
#  Accept proportion: 1.000000
#  Steps taken: 1
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 2
#  Cum regret: 0.000000
#  Steps taken: 191
#  Cum regret: 0.000000
#  Steps taken: 476
#  Cum regret: 0.000000
#  Steps taken: 71
#  Cum regret: 0.000000
# Experiment: Step 977
#  Accept proportion: 1.000000
#  Steps taken: 1
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 17
#  Cum regret: 0.000000
#  Steps taken: 84
#  Cum regret: 0.000000
#  Steps taken: 445
#  Cum regret: 0.000000
#  Steps taken: 144
#  Cum regret: 0.000000
# Experiment: Step 978
#  Accept proportion: 1.000000
#  Steps taken: 1
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 63
#  Cum regret: 0.000000
#  Steps taken: 357
#  Cum regret: 0.000000
#  Steps taken: 338
#  Cum regret: 0.000000
#  Steps taken: 12
#  Cum regret: 0.000000
# Experiment: Step 979
#  Accept proportion: 1.000000
#  Steps taken: 1
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 50
#  Cum regret: 0.000000
#  Steps taken: 201
#  Cum regret: 0.000000
#  Steps taken: 449
#  Cum regret: 0.000000
#  Steps taken: 98
#  Cum regret: 0.000000
# Experiment: Step 980
#  Accept proportion: 1.000000
#  Steps taken: 1
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 16
#  Cum regret: 0.000000
#  Steps taken: 90
#  Cum regret: 0.000000
#  Steps taken: 448
#  Cum regret: 0.000000
#  Steps taken: 7
#  Cum regret: 0.000000
# Experiment: Step 981
#  Accept proportion: 0.916667
#  Steps taken: 12
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 65
#  Cum regret: 0.000000
#  Steps taken: 364
#  Cum regret: 0.000000
#  Steps taken: 429
#  Cum regret: 0.000000
#  Steps taken: 86
#  Cum regret: 0.000000
# Experiment: Step 982
#  Accept proportion: 1.000000
#  Steps taken: 1
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 55
#  Cum regret: 0.000000
#  Steps taken: 345
#  Cum regret: 0.000000
#  Steps taken: 256
#  Cum regret: 0.000000
#  Steps taken: 21
#  Cum regret: 0.000000
# Experiment: Step 983
#  Accept proportion: 1.000000
#  Steps taken: 1
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 60
#  Cum regret: 0.000000
#  Steps taken: 360
#  Cum regret: 0.000000
#  Steps taken: 434
#  Cum regret: 0.000000
#  Steps taken: 99
#  Cum regret: 0.000000
# Experiment: Step 984
#  Accept proportion: 1.000000
#  Steps taken: 2
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 13
#  Cum regret: 0.000000
#  Steps taken: 117
#  Cum regret: 0.000000
#  Steps taken: 441
#  Cum regret: 0.000000
#  Steps taken: 127
#  Cum regret: 0.000000
# Experiment: Step 985
#  Accept proportion: 1.000000
#  Steps taken: 1
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 50
#  Cum regret: 0.000000
#  Steps taken: 204
#  Cum regret: 0.000000
#  Steps taken: 323
#  Cum regret: 0.000000
#  Steps taken: 100
#  Cum regret: 0.000000
# Experiment: Step 986
#  Accept proportion: 1.000000
#  Steps taken: 1
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 35
#  Cum regret: 0.000000
#  Steps taken: 366
#  Cum regret: 0.000000
#  Steps taken: 390
#  Cum regret: 0.000000
#  Steps taken: 78
#  Cum regret: 0.000000
# Experiment: Step 987
#  Accept proportion: 1.000000
#  Steps taken: 1
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 1
#  Cum regret: 0.000000
#  Steps taken: 413
#  Cum regret: 0.000000
#  Steps taken: 420
#  Cum regret: 0.000000
#  Steps taken: 3
#  Cum regret: 0.000000
# Experiment: Step 988
#  Accept proportion: 1.000000
#  Steps taken: 1
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 41
#  Cum regret: 0.000000
#  Steps taken: 94
#  Cum regret: 0.000000
#  Steps taken: 451
#  Cum regret: 0.000000
#  Steps taken: 70
#  Cum regret: 0.000000
# Experiment: Step 989
#  Accept proportion: 1.000000
#  Steps taken: 1
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 3
#  Cum regret: 0.000000
#  Steps taken: 149
#  Cum regret: 0.000000
#  Steps taken: 387
#  Cum regret: 0.000000
#  Steps taken: 75
#  Cum regret: 0.000000
# Experiment: Step 990
#  Accept proportion: 1.000000
#  Steps taken: 1
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 15
#  Cum regret: 0.000000
#  Steps taken: 303
#  Cum regret: 0.000000
#  Steps taken: 447
#  Cum regret: 0.000000
#  Steps taken: 50
#  Cum regret: 0.000000
# Experiment: Step 991
#  Accept proportion: 1.000000
#  Steps taken: 1
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 1
#  Cum regret: 0.000000
#  Steps taken: 496
#  Cum regret: 0.000000
#  Steps taken: 499
#  Cum regret: 0.000000
#  Steps taken: 148
#  Cum regret: 0.000000
# Experiment: Step 992
#  Accept proportion: 1.000000
#  Steps taken: 1
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 68
#  Cum regret: 0.000000
#  Steps taken: 369
#  Cum regret: 0.000000
#  Steps taken: 435
#  Cum regret: 0.000000
#  Steps taken: 70
#  Cum regret: 0.000000
# Experiment: Step 993
#  Accept proportion: 1.000000
#  Steps taken: 1
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 13
#  Cum regret: 0.000000
#  Steps taken: 86
#  Cum regret: 0.000000
#  Steps taken: 440
#  Cum regret: 0.000000
#  Steps taken: 29
#  Cum regret: 0.000000
# Experiment: Step 994
#  Accept proportion: 1.000000
#  Steps taken: 1
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 1
#  Cum regret: 0.000000
#  Steps taken: 526
#  Cum regret: 0.000000
#  Steps taken: 312
#  Cum regret: 0.000000
#  Steps taken: 59
#  Cum regret: 0.000000
# Experiment: Step 995
#  Accept proportion: 1.000000
#  Steps taken: 1
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 63
#  Cum regret: 0.000000
#  Steps taken: 349
#  Cum regret: 0.000000
#  Steps taken: 431
#  Cum regret: 0.000000
#  Steps taken: 1
#  Cum regret: 0.000000
# Experiment: Step 996
#  Accept proportion: 1.000000
#  Steps taken: 1
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 16
#  Cum regret: 0.000000
#  Steps taken: 88
#  Cum regret: 0.000000
#  Steps taken: 439
#  Cum regret: 0.000000
#  Steps taken: 125
#  Cum regret: 0.000000
# Experiment: Step 997
#  Accept proportion: 1.000000
#  Steps taken: 1
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 29
#  Cum regret: 0.000000
#  Steps taken: 357
#  Cum regret: 0.000000
#  Steps taken: 337
#  Cum regret: 0.000000
#  Steps taken: 120
#  Cum regret: 0.000000
# Experiment: Step 998
#  Accept proportion: 1.000000
#  Steps taken: 1
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 2
#  Cum regret: 0.000000
#  Steps taken: 416
#  Cum regret: 0.000000
#  Steps taken: 436
#  Cum regret: 0.000000
#  Steps taken: 116
#  Cum regret: 0.000000
# Experiment: Step 999
#  Accept proportion: 1.000000
#  Steps taken: 1
#  Cum regret: 0.000000
#  Cum regret: 0.000000
#  Steps taken: 3
#  Cum regret: 0.000000
#  Steps taken: 161
#  Cum regret: 0.000000
#  Steps taken: 431
#  Cum regret: 0.000000
#  Steps taken: 119
#  Cum regret: 0.000000
# Drawing sample 1
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-cec4cfedb942> in <module>()
#      67 agents = [agent0] + agents
#      68 for agent in agents:
# ---> 69     samples = redraw_samples(agent, 1000, 2)
#      70     samples_list += [samples]
#      71 samples_list = np.asarray(samples_list)
#
# /n/fs/grad/holdenl/code/ts_tutorial/src/compare_utils.pyc in redraw_samples(agent, num, verbosity)
#      90         printv("Drawing sample %d" % (i+1), verbosity, 1)
#      91         #agent_copy.theta= theta
# ---> 92         s = agent_copy.get_sample()
#      93         samples += [s]
#      94         printv(" "+repr(s), verbosity, 2)
#
# /n/fs/grad/holdenl/code/ts_tutorial/src/logistic/agent_logistic.pyc in get_sample(self)
#     703                                         time_limit=self.time,
#     704                                         step_size = self.step_size(self.num_plays), n_steps = self.n_steps, init_pt = self.theta,
# --> 705                                         leapfrog = self.leapfrog)
#     706         printv(" Sample: " + repr(self.theta), self.v, 2)
#     707         printv(" Accept proportion: %f" % self.accepts, self.v, 1)
#
# /n/fs/grad/holdenl/code/ts_tutorial/src/algorithms/langevin.pyc in mala(d, data, f, prior_f, grad_f, prior_grad_f, step_size, n_steps, init_pt, time_limit, leapfrog)
#     157     start = time.time()
#     158     for t in range(n_steps):
# --> 159         x, accept, _ = (mala_lf_step if leapfrog else mala_step)(d, data, f, prior_f, grad_f, prior_grad_f, x, step_size)
#     160         if accept:
#     161             accepts += 1
#
# /n/fs/grad/holdenl/code/ts_tutorial/src/algorithms/langevin.pyc in mala_lf_step(d, data, f, prior_f, grad_f, prior_grad_f, x, step_size)
#     144     gz = np.sum(grads_z, axis=0) + prior_grad_f(z)
#     145     v = noise - np.sqrt(step_size/2)*g - np.sqrt(step_size/2)*gz
# --> 146     p = np.exp(H(z,v)-H(x,noise))
#     147     (samp, accept) = (z, True) if np.random.random()<p else (x, False)
#     148     #samp = z if np.random.random()<p else x
#
# /n/fs/grad/holdenl/code/ts_tutorial/src/algorithms/langevin.pyc in H(x, v)
#     140         scaled_noise
#     141     def H(x,v):
# --> 142         return np.sum(f(x,data), axis=0) + prior_f(x) + 0.5*np.sum(np.square(v))
#     143     grads_z = grad_f(z, data)
#     144     gz = np.sum(grads_z, axis=0) + prior_grad_f(z)
#
# /n/fs/grad/holdenl/code/ts_tutorial/src/algorithms/langevin.pyc in logistic_f(x, data)
#      38     zs = data[0]
#      39     ys = data[1]
# ---> 40     return evaluate_log1pexp(x.dot(zs.T)) - ys * x.dot(zs.T)
#      41
#      42 class Gaussian_prior_grad_f(object):
#
# KeyboardInterrupt:
